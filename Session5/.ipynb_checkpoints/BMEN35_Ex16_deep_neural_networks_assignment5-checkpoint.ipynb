# %% [markdown]
# <a href="https://colab.research.google.com/github/antfolk/BMEN35_2023/blob/main/Session5/BMEN35_Ex16_deep_neural_networks_assignment5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 5
# ## Fill in your name below
# ----<font color=Green>Mosa Hosseini </font>-----
#
# ## Your mission is now the following:
#
# You will use a (a modified version of a) dataset named HAM10000 ("Human Against Machine with 10000 training images")  (https://doi.org/10.7910/DVN/DBW86T). The dataset contains dermatoscopic images from different populations, acquired and stored by different modalities. The original dataset consists of 10015 dermatoscopic images, in 600x450x3 pixel resolution, which can serve as a training set for academic machine learning purposes.  Cases include a representative collection of all important diagnostic categories in the realm of pigmented lesions: Actinic keratoses and intraepithelial carcinoma / Bowen's disease (akiec), basal cell carcinoma (bcc), benign keratosis-like lesions (solar lentigines / seborrheic keratoses and lichen-planus like keratoses, bkl), dermatofibroma (df), melanoma (mel), melanocytic nevi (nv) and vascular lesions (angiomas, angiokeratomas, pyogenic granulomas and hemorrhage, vasc).
#
# More than 50% of lesions are confirmed through histopathology (histo), the ground truth for the rest of the cases is either follow-up examination (follow_up), expert consensus (consensus), or confirmation by in-vivo confocal microscopy (confocal).
#
# For this exercise we have downsampled the images to 100x75x3 and randomly taken 1400 samples from the original 10015 to make training times more reasonable. We have also made the dataset more balanced in terms of class distributions.
#
# Make sure you have downloaded the `HAM1400_100_75.zip` file from Canvas to your computer.
#
# Some tips and tricks (colab):
# * Copy the dataset to google drive and copy it to the colab workspace instead of uploading it. This will save you time, if don't finish the exercise in one go.
# * If you feel adventurous you can download and try some of the other resolutions and datasets (available in Canvas). There are 100x75, 256x192, 600x450 resolutions of images and the full datasets with ~10000 images and the "downsampled" datasets with 1400 images. If you use any of the other be prepared for looooong training times.
# * You may also want to experiment with changing runtime in google colab (too eg GPU) and see how much faster training will be. **PLEASE NOTE THAT YOU MIGHT GET THROWN OUT OF USING GPU/TPU RUNTIMES. ONLY THE CPU RUNTIMES ARE FREE.**
#
# We will start you off with loading the data and such and some (**maybe not all!**) of the relevant imports.

# %%
# Here you will upload the files
from google.colab import files
file = files.upload() # Choose HAM1400_100_75.zip

# %%
# OPTIONAL IF YOU ALREADY HAVE COPIED THE DATASET TO GOOGLE DRIVE
# This mounts your google drive
from google.colab import drive
drive.mount('/content/drive')

# !cp -r /content/drive/MyDrive/data/HAM1400_100_75.zip /content/

# %%
# I use jupyte notebook
# import os
# name = 'HAM1400_100_75.zip'
# import zipfile as zf
# files = zf.ZipFile(name, 'r')
# files.extractall()
# files.close()

# %%
# !pip install opencv-python

# %%
# This unzips the files
# !unzip -q /content/HAM1400_100_75.zip -d /content/

# %% [markdown]
# Now we have the data in our workspace. Lets do some imports.

# %%
import os
from glob import glob
import cv2
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from PIL import Image
from matplotlib import pyplot as plt

from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Flatten
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.optimizers import SGD, RMSprop, Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import regularizers
from keras.applications.inception_v3 import InceptionV3

# %% [markdown]
# Now we will read the data into Python.

# %%
# First read metadata into a dataframe
#base_dir = 'HAM1400_100_75/'

base_dir = "HAM1400_100_75/"

skin_df=pd.read_csv(base_dir + 'dataframe.csv')
# How many rows, that is how many images are there
length = skin_df.shape[0]
# Create a dictionary for the labels
label_dict = {'nv': 0,'mel': 1,'bkl': 2, 'bcc': 3, 'akiec': 4,'vasc': 5,'df': 6 }
# Recode labels in dataframe to be numbers
skin_df['labels'] = skin_df['dx'].map(label_dict)
#Allocate space for X and y aka our data and labels
#X = np.zeros((length,32,32,3))


#X = np.zeros((length,299,299,3))
X = np.zeros((length,75,100,3))

y = np.zeros((length))
k = 0
for i in skin_df['image_id']: # Get filename from dataframe
  #print(k)
#    X[k,:,:,:] = cv2.resize(np.asarray(Image.open(base_dir +  i + '.jpg')) , (299,299)) 
    X[k,:,:,:] = np.asarray(Image.open(base_dir +  i + '.jpg'))
    k= k+1

y = np.asarray(skin_df['labels'])

# %% [markdown]
# ### <font color=Green> Exploratory data analyses</font>

# %%
w

# %%
w = dict(skin_df['dx'].value_counts() )

df = pd.DataFrame.from_dict(w, orient='index')

df.plot(kind ="bar")
# Out:
# <AxesSubplot: >

# %% [markdown]
# We will do the usual conversion as before.

# %%
# Convert data to float and scale to be between 0 and 1
X = X.astype('float32')
X /=255.0
yidx = y
y = to_categorical(y) # One-hot encode the labels
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2 )

# i delete X because it takes alot of memory to store X
#del(X)

# %% [markdown]
# Let's plot the data and visualise what kind of data we are dealing with.

# %%
plt.figure(figsize=(16, 14))
plt.subplot(3, 3, 1)
plt.title('Example of melanocytic nevi (nv)')
plt.imshow(X[np.where(yidx == 0)[0][0], :, :])
plt.subplot(3, 3, 2)
plt.title('Example of melanoma (mel)')
plt.imshow(X[np.where(yidx == 1)[0][0], :, :])
plt.subplot(3, 3, 3)
plt.title('Example of benign keratosis-like lesions (bkl)')
plt.imshow(X[np.where(yidx == 2)[0][0], :, :])
plt.subplot(3, 3, 4)
plt.title('Example of basal cell carcinoma (bcc)')
plt.imshow(X[np.where(yidx == 3)[0][0], :, :])
plt.subplot(3, 3, 5)
plt.title('Actinic keratoses and intraepithelial carcinoma (akiec)')
plt.imshow(X[np.where(yidx == 4)[0][0], :, :])
plt.subplot(3, 3, 6)
plt.title('Example of vascular lesions (vasc)')
plt.imshow(X[np.where(yidx == 5)[0][0], :, :])
plt.subplot(3, 3, 7)
plt.title('Example of dermatofibroma (df)')
plt.imshow(X[np.where(yidx == 6)[0][0], :, :])
plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.optimizers import SGD, RMSprop, Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import regularizers

from keras.applications.inception_v3 import InceptionV3

# %%
# We will use the Sequential model
model = Sequential()
# We will add some layers to this model
model.add(Conv2D(32, (3, 3), activation='relu', padding = 'same',
                input_shape=(75, 100, 3)))
model.add(Conv2D(64, (2,2) , activation= 'relu', kernel_initializer='he_uniform' ))

model.add(MaxPooling2D((2, 2)))
#model.add(BatchNormalization())

#model.add(Conv2D(32, (3,3) , activation= 'relu' , kernel_initializer='he_uniform'))
model.add(Conv2D(32, kernel_size = (3,3), activation = 'relu' ,kernel_initializer='he_uniform'))
#model.add(Conv2D(16 , kernel_size = (2,2), activation = 'relu',kernel_initializer='he_uniform'))
model.add(MaxPooling2D((2, 2)))

#model.add(BatchNormalization())


#model.add(Conv2D(128, kernel_size = (3,3), activation = 'relu'))
#model.add(Conv2D(256, kernel_size = (3,3), activation = 'relu',kernel_initializer='he_uniform'))


model.add(Flatten())
model.add(Dropout(0.2))

# model.add(Dense(256, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dropout(0.1))


model.add(Dense(128, activation= "relu"))
#model.add(BatchNormalization())


model.add(Dense(64, activation= "relu"))
#model.add(BatchNormalization())
model.add(Dropout(0.1))


model.add(Dense(32, activation= "relu"))
#model.add(BatchNormalization())

model.add(Dense(7, activation='softmax'))
# compile model
#opt = SGD(learning_rate=0.01 , momentum=0.1)
opt = Adam(learning_rate = 0.001)
early_stopping = EarlyStopping(monitor='val_accuracy', patience=5,
                               restore_best_weights=True)

model.compile(optimizer=opt, loss='categorical_crossentropy',
              metrics=['accuracy'])
model.summary()


#plot_model(model, show_shapes=True, show_layer_names=True, show_layer_activations=True) # This also generates a file of the plot
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_22 (Conv2D)          (None, 75, 100, 32)       896
#
#  conv2d_23 (Conv2D)          (None, 74, 99, 64)        8256
#
#  max_pooling2d_6 (MaxPooling  (None, 37, 49, 64)       0
#  2D)
#
#  conv2d_24 (Conv2D)          (None, 35, 47, 32)        18464
#
#  max_pooling2d_7 (MaxPooling  (None, 17, 23, 32)       0
#  2D)
#
#  flatten_6 (Flatten)         (None, 12512)             0
#
#  dropout_16 (Dropout)        (None, 12512)             0
#
#  dense_24 (Dense)            (None, 128)               1601664
#
#  dense_25 (Dense)            (None, 64)                8256
#
#  dropout_17 (Dropout)        (None, 64)                0
#
#  dense_26 (Dense)            (None, 32)                2080
#
#  dense_27 (Dense)            (None, 7)                 231
#
# =================================================================
# Total params: 1,639,847
# Trainable params: 1,639,847
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train,validation_data=(X_test, y_test), 
                    epochs=100,shuffle=True ,batch_size=64, verbose=1, callbacks=[early_stopping])


y_hatt = model.predict(X_test)
a = np.argmax(y_hatt, axis =1 )
b = np.argmax(y_test,axis =1)
from sklearn.metrics import classification_report 
print(classification_report(a, b))
# Out:
# Epoch 1/100
# 18/18 [==============================] - 5s 246ms/step - loss: 1.9143 - accuracy: 0.2071 - val_loss: 1.8278 - val_accuracy: 0.2562
# Epoch 2/100
# 18/18 [==============================] - 4s 237ms/step - loss: 1.7400 - accuracy: 0.2973 - val_loss: 1.7329 - val_accuracy: 0.3310
# Epoch 3/100
# 18/18 [==============================] - 4s 244ms/step - loss: 1.6862 - accuracy: 0.3473 - val_loss: 1.7211 - val_accuracy: 0.3452
# Epoch 4/100
# 18/18 [==============================] - 4s 234ms/step - loss: 1.6405 - accuracy: 0.3518 - val_loss: 1.7310 - val_accuracy: 0.3025
# Epoch 5/100
# 18/18 [==============================] - 4s 240ms/step - loss: 1.6213 - accuracy: 0.3607 - val_loss: 1.6361 - val_accuracy: 0.3274
# Epoch 6/100
# 18/18 [==============================] - 4s 239ms/step - loss: 1.5433 - accuracy: 0.3866 - val_loss: 1.6394 - val_accuracy: 0.3665
# Epoch 7/100
# 18/18 [==============================] - 4s 242ms/step - loss: 1.4530 - accuracy: 0.4634 - val_loss: 1.4919 - val_accuracy: 0.4057
# Epoch 8/100
# 18/18 [==============================] - 4s 242ms/step - loss: 1.3567 - accuracy: 0.4723 - val_loss: 1.4316 - val_accuracy: 0.4769
# Epoch 9/100
# 18/18 [==============================] - 4s 233ms/step - loss: 1.2994 - accuracy: 0.5000 - val_loss: 1.3781 - val_accuracy: 0.4698
# Epoch 10/100
# 18/18 [==============================] - 4s 236ms/step - loss: 1.3143 - accuracy: 0.4920 - val_loss: 1.3803 - val_accuracy: 0.4698
# Epoch 11/100
# 18/18 [==============================] - 4s 236ms/step - loss: 1.2117 - accuracy: 0.5286 - val_loss: 1.3057 - val_accuracy: 0.5160
# Epoch 12/100
# 18/18 [==============================] - 4s 227ms/step - loss: 1.1516 - accuracy: 0.5643 - val_loss: 1.3856 - val_accuracy: 0.4555
# Epoch 13/100
# 18/18 [==============================] - 4s 235ms/step - loss: 1.1484 - accuracy: 0.5500 - val_loss: 1.3629 - val_accuracy: 0.5445
# Epoch 14/100
# 18/18 [==============================] - 4s 234ms/step - loss: 1.0394 - accuracy: 0.6000 - val_loss: 1.3412 - val_accuracy: 0.4804
# Epoch 15/100
# 18/18 [==============================] - 4s 227ms/step - loss: 0.9832 - accuracy: 0.6223 - val_loss: 1.3780 - val_accuracy: 0.5089
# Epoch 16/100
# 18/18 [==============================] - 4s 227ms/step - loss: 0.9601 - accuracy: 0.6223 - val_loss: 1.4049 - val_accuracy: 0.4911
# Epoch 17/100
# 18/18 [==============================] - 4s 230ms/step - loss: 0.9659 - accuracy: 0.6330 - val_loss: 1.3775 - val_accuracy: 0.4840
# Epoch 18/100
# 18/18 [==============================] - 4s 233ms/step - loss: 0.8947 - accuracy: 0.6714 - val_loss: 1.3629 - val_accuracy: 0.4982
# 9/9 [==============================] - 1s 40ms/step
#               precision    recall  f1-score   support
#
#            0       0.73      0.71      0.72        63
#            1       0.46      0.66      0.54        29
#            2       0.62      0.37      0.47        67
#            3       0.61      0.52      0.56        54
#            4       0.43      0.44      0.44        43
#            5       0.65      0.79      0.71        19
#            6       0.08      0.33      0.13         6
#
#     accuracy                           0.54       281
#    macro avg       0.51      0.55      0.51       281
# weighted avg       0.59      0.54      0.55       281

# %%
from sklearn.metrics import classification_report 
print(classification_report(a, b))

# %%
h = history.history
const = len(h["accuracy"])
plt.figure()
plt.plot( np.linspace(1, const,const ), h["accuracy"])
plt.plot(np.linspace(1, const,const ), h["val_accuracy"] )
plt.title("Accuracy")
plt.legend(["Train accuracy" , "Validation accuracy"] )
plt.show()

plt.figure()
plt.plot( np.linspace(1, const,const ), h["loss"])
plt.plot(np.linspace(1, const,const ), h["val_loss"] )
plt.title("Loss")
plt.legend(["Train accuracy" , "Validation accuracy"] )
plt.show()

# %% [markdown]
# ## <font color = BLUE> Transfer learning on the downsampeled dataset </font>

# %%
#######################                                 *****************************
#######################    Transfer learning       *****************************
#######################                                 *****************************

#         Let's finetune a pre existing model             # 


#system specification 
# GPU : RTX 3080 10 gb 
# RAM : 24 GB 
#Intel(R) Xeon(R) CPU E5-2640 v3 @ 2.60GHz

# %%
from tensorflow.keras.layers import Input , Dropout ,GlobalAveragePooling2D

# %%
from tensorflow.keras.applications import Xception
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input , Dropout ,GlobalAveragePooling2D
from tensorflow.keras import layers, models 

base_model = Xception(
    include_top=False,
    input_shape=(75,100,3) ,
    weights="imagenet",
    input_tensor=None,
    pooling="max")

# add a global spatial average pooling layer
XX = base_model.output
XX = Flatten()(XX)
XX = Dropout(0.2)(XX)
# let's add a fully-connected layer
# XX = Dense(512, activation='relu')(XX)
# XX = Dropout(0.1)(XX)
# XX = BatchNormalization()(XX)
# XX = Dense(128, activation='relu')(XX)
# XX = Dropout(0.1)(XX)
# XX = BatchNormalization()(XX)
# XX = Dense(64, activation='relu')(XX)
# XX = Dropout(0.1)(XX)
# XX = BatchNormalization()(XX)
# XX = Dense(32, activation='relu')(XX)

# new config
XX = Dense(256, activation='relu')(XX)
XX = Dropout(0.2)(XX)
XX = BatchNormalization()(XX)
XX = Dense(128, activation='relu')(XX)
XX = Dropout(0.2)(XX)
XX = Dense(64, activation='relu')(XX)
XX = Dropout(0.1)(XX)
predictions = Dense(7, activation='softmax')(XX)

model = Model(inputs=base_model.input, outputs=predictions)


#unfreez the last 20 layers
for layer in model.layers[0:-20]:
    layer.trainable = False
for layer in model.layers[-20:]:
    layer.trainable = True

model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy',metrics=["accuracy"])



# we train our model again (this time fine-tuning the top 2 inception blocks
# alongside the top Dense layers

early_stopping = EarlyStopping(monitor='val_accuracy', patience=10,
                               restore_best_weights=True)


#model.summary()
history = model.fit(X_train, y_train,validation_data=(X_test, y_test), 
                       epochs=100 ,batch_size=128, verbose=1, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 9/9 [==============================] - 18s 1s/step - loss: 2.4531 - accuracy: 0.1187 - val_loss: 1.9283 - val_accuracy: 0.1886
# Epoch 2/100
# 9/9 [==============================] - 9s 1s/step - loss: 2.1493 - accuracy: 0.1688 - val_loss: 1.8511 - val_accuracy: 0.2562
# Epoch 3/100
# 9/9 [==============================] - 10s 1s/step - loss: 1.8406 - accuracy: 0.2714 - val_loss: 1.8223 - val_accuracy: 0.2669
# Epoch 4/100
# 9/9 [==============================] - 10s 1s/step - loss: 1.6905 - accuracy: 0.3420 - val_loss: 1.8056 - val_accuracy: 0.2669
# Epoch 5/100
# 9/9 [==============================] - 9s 1s/step - loss: 1.5750 - accuracy: 0.3973 - val_loss: 1.7881 - val_accuracy: 0.2705
# Epoch 6/100
# 9/9 [==============================] - 9s 1s/step - loss: 1.5024 - accuracy: 0.4536 - val_loss: 1.7787 - val_accuracy: 0.2705
# Epoch 7/100
# 9/9 [==============================] - 9s 1s/step - loss: 1.4259 - accuracy: 0.4598 - val_loss: 1.7688 - val_accuracy: 0.2847
# Epoch 8/100
# 9/9 [==============================] - 9s 1s/step - loss: 1.3450 - accuracy: 0.4938 - val_loss: 1.7520 - val_accuracy: 0.2811
# Epoch 9/100
# 9/9 [==============================] - 9s 1s/step - loss: 1.3100 - accuracy: 0.5455 - val_loss: 1.7405 - val_accuracy: 0.2847
# Epoch 10/100
# 9/9 [==============================] - 9s 1s/step - loss: 1.2171 - accuracy: 0.5848 - val_loss: 1.7487 - val_accuracy: 0.2705
# Epoch 11/100
# 9/9 [==============================] - 9s 1s/step - loss: 1.1363 - accuracy: 0.6036 - val_loss: 1.7550 - val_accuracy: 0.2705
# Epoch 12/100
# 9/9 [==============================] - 9s 1s/step - loss: 1.1084 - accuracy: 0.6295 - val_loss: 1.7479 - val_accuracy: 0.2776
# Epoch 13/100
# 9/9 [==============================] - 9s 1s/step - loss: 1.0393 - accuracy: 0.6411 - val_loss: 1.7346 - val_accuracy: 0.2918
# Epoch 14/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.9843 - accuracy: 0.6875 - val_loss: 1.7158 - val_accuracy: 0.2918
# Epoch 15/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.9502 - accuracy: 0.6973 - val_loss: 1.7074 - val_accuracy: 0.2989
# Epoch 16/100
# 9/9 [==============================] - 9s 993ms/step - loss: 0.8858 - accuracy: 0.7402 - val_loss: 1.6681 - val_accuracy: 0.3238
# Epoch 17/100
# 9/9 [==============================] - 9s 996ms/step - loss: 0.8450 - accuracy: 0.7402 - val_loss: 1.6395 - val_accuracy: 0.3381
# Epoch 18/100
# 9/9 [==============================] - 9s 993ms/step - loss: 0.8095 - accuracy: 0.7509 - val_loss: 1.6735 - val_accuracy: 0.3310
# Epoch 19/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.7502 - accuracy: 0.7795 - val_loss: 1.6602 - val_accuracy: 0.3310
# Epoch 20/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.6964 - accuracy: 0.7991 - val_loss: 1.6138 - val_accuracy: 0.3594
# Epoch 21/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.6344 - accuracy: 0.8259 - val_loss: 1.5776 - val_accuracy: 0.3737
# Epoch 22/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.6168 - accuracy: 0.8348 - val_loss: 1.5668 - val_accuracy: 0.3843
# Epoch 23/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.5687 - accuracy: 0.8536 - val_loss: 1.5994 - val_accuracy: 0.3808
# Epoch 24/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.5169 - accuracy: 0.8687 - val_loss: 1.5825 - val_accuracy: 0.4021
# Epoch 25/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.4808 - accuracy: 0.8884 - val_loss: 1.5198 - val_accuracy: 0.4342
# Epoch 26/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.4453 - accuracy: 0.9054 - val_loss: 1.4857 - val_accuracy: 0.4377
# Epoch 27/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.4246 - accuracy: 0.8929 - val_loss: 1.4832 - val_accuracy: 0.4448
# Epoch 28/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.3877 - accuracy: 0.9143 - val_loss: 1.4766 - val_accuracy: 0.4626
# Epoch 29/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.3396 - accuracy: 0.9312 - val_loss: 1.4863 - val_accuracy: 0.4555
# Epoch 30/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.3333 - accuracy: 0.9312 - val_loss: 1.4712 - val_accuracy: 0.4698
# Epoch 31/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.3066 - accuracy: 0.9402 - val_loss: 1.4589 - val_accuracy: 0.4804
# Epoch 32/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.2900 - accuracy: 0.9482 - val_loss: 1.4357 - val_accuracy: 0.4804
# Epoch 33/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.2587 - accuracy: 0.9536 - val_loss: 1.4358 - val_accuracy: 0.4911
# Epoch 34/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.2507 - accuracy: 0.9571 - val_loss: 1.4340 - val_accuracy: 0.4911
# Epoch 35/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.2260 - accuracy: 0.9563 - val_loss: 1.4415 - val_accuracy: 0.5053
# Epoch 36/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.2111 - accuracy: 0.9598 - val_loss: 1.4455 - val_accuracy: 0.4947
# Epoch 37/100
# 9/9 [==============================] - 9s 976ms/step - loss: 0.1948 - accuracy: 0.9634 - val_loss: 1.4646 - val_accuracy: 0.4982
# Epoch 38/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.1682 - accuracy: 0.9714 - val_loss: 1.5033 - val_accuracy: 0.4875
# Epoch 39/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.1549 - accuracy: 0.9777 - val_loss: 1.4730 - val_accuracy: 0.4982
# Epoch 40/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.1609 - accuracy: 0.9723 - val_loss: 1.4424 - val_accuracy: 0.4982
# Epoch 41/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.1274 - accuracy: 0.9857 - val_loss: 1.4531 - val_accuracy: 0.5053
# Epoch 42/100
# 9/9 [==============================] - 10s 1s/step - loss: 0.1284 - accuracy: 0.9839 - val_loss: 1.4881 - val_accuracy: 0.5231
# Epoch 43/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.1300 - accuracy: 0.9812 - val_loss: 1.4826 - val_accuracy: 0.5160
# Epoch 44/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.1012 - accuracy: 0.9893 - val_loss: 1.4872 - val_accuracy: 0.5267
# Epoch 45/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.1057 - accuracy: 0.9857 - val_loss: 1.4853 - val_accuracy: 0.5302
# Epoch 46/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.0965 - accuracy: 0.9866 - val_loss: 1.4830 - val_accuracy: 0.5409
# Epoch 47/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.0999 - accuracy: 0.9875 - val_loss: 1.4802 - val_accuracy: 0.5445
# Epoch 48/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.0818 - accuracy: 0.9929 - val_loss: 1.5039 - val_accuracy: 0.5516
# Epoch 49/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.0744 - accuracy: 0.9937 - val_loss: 1.5288 - val_accuracy: 0.5516
# Epoch 50/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.0758 - accuracy: 0.9911 - val_loss: 1.5373 - val_accuracy: 0.5409
# Epoch 51/100
# 9/9 [==============================] - 9s 988ms/step - loss: 0.0694 - accuracy: 0.9964 - val_loss: 1.5373 - val_accuracy: 0.5445
# Epoch 52/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.0698 - accuracy: 0.9955 - val_loss: 1.5419 - val_accuracy: 0.5445
# Epoch 53/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.0631 - accuracy: 0.9911 - val_loss: 1.5578 - val_accuracy: 0.5338
# Epoch 54/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.0582 - accuracy: 0.9964 - val_loss: 1.5824 - val_accuracy: 0.5302
# Epoch 55/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.0664 - accuracy: 0.9884 - val_loss: 1.5593 - val_accuracy: 0.5338
# Epoch 56/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.0660 - accuracy: 0.9893 - val_loss: 1.5479 - val_accuracy: 0.5445
# Epoch 57/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.0523 - accuracy: 0.9964 - val_loss: 1.5702 - val_accuracy: 0.5267
# Epoch 58/100
# 9/9 [==============================] - 9s 1s/step - loss: 0.0537 - accuracy: 0.9937 - val_loss: 1.5732 - val_accuracy: 0.5267

# %%
# #model.summary()
# for i in model.layers[-12:]:
#     print(i.name)
# len(model.layers)

# %%
y_hatt = model.predict(X_test)
a = np.argmax(y_hatt, axis =1 )
b = np.argmax(y_test,axis =1)
from sklearn.metrics import classification_report 
print(classification_report(a, b))
# Out:
# 9/9 [==============================] - 3s 241ms/step
#               precision    recall  f1-score   support
#
#            0       0.81      0.68      0.74        74
#            1       0.51      0.49      0.50        43
#            2       0.30      0.31      0.30        39
#            3       0.43      0.59      0.50        34
#            4       0.57      0.45      0.51        55
#            5       0.70      0.76      0.73        21
#            6       0.44      0.73      0.55        15
#
#     accuracy                           0.55       281
#    macro avg       0.54      0.57      0.55       281
# weighted avg       0.57      0.55      0.56       281

# %%
h = history.history
const = len(h["accuracy"])
plt.figure()
plt.plot( np.linspace(1, const,const ), h["accuracy"])
plt.plot(np.linspace(1, const,const ), h["val_accuracy"] )
plt.title("Accuracy")
plt.legend(["Train accuracy" , "Validation accuracy"] )
plt.show()

plt.figure()
plt.plot( np.linspace(1, const,const ), h["loss"])
plt.plot(np.linspace(1, const,const ), h["val_loss"] )
plt.title("Loss")
plt.legend(["Train accuracy" , "Validation accuracy"] )
plt.show()

# %%
# del(X_train)
# del(X_test)
# model.save("transfer_learning_Xception")
# model.save_weights("transfer_learning_Xception_saved_weights.h5")
from sklearn.metrics import confusion_matrix
a = np.argmax(y_hatt, axis =1 )
b = np.argmax(y_test,axis =1)
cm =confusion_matrix(a, b)

# %%
import seaborn as sns
plt.figure()
sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)       
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
sns.heatmap(cm/np.sum(cm), annot=True, 
            fmt='.1%', cmap='Blues',vmin=0,cbar=False)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# ## <font color = BLUE > Transfer learning on the original dataset. </font>

# %%
import os
from glob import glob
import cv2
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from PIL import Image
from matplotlib import pyplot as plt

from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Flatten
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.optimizers import SGD, RMSprop, Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import regularizers
from keras.applications.inception_v3 import InceptionV3

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.optimizers import SGD, RMSprop, Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import regularizers

from keras.applications.inception_v3 import InceptionV3

# %%
# First read metadata into a dataframe
#base_dir = 'HAM1400_100_75/'

base_dir = "HAM10000_600_450/"

skin_df=pd.read_csv(base_dir + 'dataframe.csv')
# How many rows, that is how many images are there
length = skin_df.shape[0]
# Create a dictionary for the labels
label_dict = {'nv': 0,'mel': 1,'bkl': 2, 'bcc': 3, 'akiec': 4,'vasc': 5,'df': 6 }
# Recode labels in dataframe to be numbers
skin_df['labels'] = skin_df['dx'].map(label_dict)
#Allocate space for X and y aka our data and labels
#X = np.zeros((length,32,32,3))


X = np.zeros((length,300,300,3))
#X = np.zeros((length,450,450,3))

y = np.zeros((length))
k = 0
for i in skin_df['image_id']: # Get filename from dataframe
  #print(k)
    X[k,:,:,:] = cv2.resize(np.asarray(Image.open(base_dir +  i + '.jpg')) , (300,300)) 
#    X[k,:,:,:] = np.asarray(Image.open(base_dir +  i + '.jpg'))
    k= k+1

y = np.asarray(skin_df['labels'])

# %%
w = dict(skin_df['dx'].value_counts() )

df = pd.DataFrame.from_dict(w, orient='index')

df.plot(kind ="bar")

# unbalanced dataset
# Out:
# <AxesSubplot: >

# %%
from tqdm import tqdm
for i in tqdm(range(len(X))):
    X[i,:,:,:] =  X[i,:,:,:].astype("float32")/255.0
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 10015/10015 [00:59<00:00, 168.10it/s]

# %%
# Convert data to float and scale to be between 0 and 1
#X = X.astype('float32')
#X /=255.0
yidx = y

plt.figure(figsize=(16, 14))
plt.subplot(3, 3, 1)
plt.title('Example of melanocytic nevi (nv)')
plt.imshow(X[np.where(yidx == 0)[0][0], :, :])
plt.subplot(3, 3, 2)
plt.title('Example of melanoma (mel)')
plt.imshow(X[np.where(yidx == 1)[0][0], :, :])
plt.subplot(3, 3, 3)
plt.title('Example of benign keratosis-like lesions (bkl)')
plt.imshow(X[np.where(yidx == 2)[0][0], :, :])
plt.subplot(3, 3, 4)
plt.title('Example of basal cell carcinoma (bcc)')
plt.imshow(X[np.where(yidx == 3)[0][0], :, :])
plt.subplot(3, 3, 5)
plt.title('Actinic keratoses and intraepithelial carcinoma (akiec)')
plt.imshow(X[np.where(yidx == 4)[0][0], :, :])
plt.subplot(3, 3, 6)
plt.title('Example of vascular lesions (vasc)')
plt.imshow(X[np.where(yidx == 5)[0][0], :, :])
plt.subplot(3, 3, 7)
plt.title('Example of dermatofibroma (df)')
plt.imshow(X[np.where(yidx == 6)[0][0], :, :])
plt.show()

# %%
y = to_categorical(y) # One-hot encode the labels
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2 )
del(X)
del(y)
del(yidx)

# %%
from tensorflow.keras.applications import Xception
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input , Dropout ,GlobalAveragePooling2D
from tensorflow.keras import layers, models 

base_model = Xception(
    include_top=False,
    input_shape=(300,300,3) ,
    weights="imagenet",
    input_tensor=None,
    pooling="max")

# add a global spatial average pooling layer
XX = base_model.output
XX = Flatten()(XX)
XX = Dropout(0.2)(XX)
# let's add a fully-connected layer
# XX = Dense(512, activation='relu')(XX)
# XX = Dropout(0.1)(XX)
# XX = BatchNormalization()(XX)
# XX = Dense(128, activation='relu')(XX)
# XX = Dropout(0.1)(XX)
# XX = BatchNormalization()(XX)
# XX = Dense(64, activation='relu')(XX)
# XX = Dropout(0.1)(XX)
# XX = BatchNormalization()(XX)
# XX = Dense(32, activation='relu')(XX)

# new config
XX = Dense(256, activation='relu')(XX)
XX = Dropout(0.2)(XX)
XX = BatchNormalization()(XX)
XX = Dense(128, activation='relu')(XX)
XX = Dropout(0.2)(XX)
XX = Dense(64, activation='relu')(XX)
predictions = Dense(7, activation='softmax')(XX)

model = Model(inputs=base_model.input, outputs=predictions)


for layer in model.layers[0:-12]:
    layer.trainable = False
for layer in model.layers[-12:]:
    layer.trainable = True

model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy',metrics=["accuracy"])



# we train our model again (this time fine-tuning the top 2 inception blocks
# alongside the top Dense layers

early_stopping = EarlyStopping(monitor='val_accuracy', patience=10,
                               restore_best_weights=True)


#model.summary()
history = model.fit(X_train, y_train,validation_data=(X_test, y_test), 
                       epochs=100 ,batch_size=64, verbose=1, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 126/126 [==============================] - 592s 5s/step - loss: 1.4565 - accuracy: 0.5100 - val_loss: 0.9601 - val_accuracy: 0.6965
# Epoch 2/100
# 126/126 [==============================] - 522s 4s/step - loss: 1.0074 - accuracy: 0.6724 - val_loss: 0.8694 - val_accuracy: 0.7194
# Epoch 3/100
# 126/126 [==============================] - 515s 4s/step - loss: 0.9403 - accuracy: 0.6826 - val_loss: 0.8281 - val_accuracy: 0.7139
# Epoch 4/100
# 126/126 [==============================] - 511s 4s/step - loss: 0.8875 - accuracy: 0.6933 - val_loss: 0.7822 - val_accuracy: 0.7304
# Epoch 5/100
# 126/126 [==============================] - 517s 4s/step - loss: 0.8457 - accuracy: 0.7057 - val_loss: 0.7483 - val_accuracy: 0.7459
# Epoch 6/100
# 126/126 [==============================] - 518s 4s/step - loss: 0.8132 - accuracy: 0.7082 - val_loss: 0.7262 - val_accuracy: 0.7444
# Epoch 7/100
# 126/126 [==============================] - 520s 4s/step - loss: 0.7915 - accuracy: 0.7156 - val_loss: 0.7258 - val_accuracy: 0.7444
# Epoch 8/100
# 126/126 [==============================] - 516s 4s/step - loss: 0.7679 - accuracy: 0.7257 - val_loss: 0.7109 - val_accuracy: 0.7504
# Epoch 9/100
# 126/126 [==============================] - 511s 4s/step - loss: 0.7452 - accuracy: 0.7288 - val_loss: 0.6881 - val_accuracy: 0.7539
# Epoch 10/100
# 126/126 [==============================] - 520s 4s/step - loss: 0.7261 - accuracy: 0.7364 - val_loss: 0.6838 - val_accuracy: 0.7559
# Epoch 11/100
# 126/126 [==============================] - 558s 4s/step - loss: 0.7081 - accuracy: 0.7415 - val_loss: 0.6787 - val_accuracy: 0.7564
# Epoch 12/100
# 126/126 [==============================] - 534s 4s/step - loss: 0.6931 - accuracy: 0.7512 - val_loss: 0.6659 - val_accuracy: 0.7688
# Epoch 13/100
# 126/126 [==============================] - 508s 4s/step - loss: 0.6725 - accuracy: 0.7521 - val_loss: 0.6586 - val_accuracy: 0.7649
# Epoch 14/100
# 126/126 [==============================] - 515s 4s/step - loss: 0.6721 - accuracy: 0.7531 - val_loss: 0.6419 - val_accuracy: 0.7639
# Epoch 15/100
# 126/126 [==============================] - 512s 4s/step - loss: 0.6681 - accuracy: 0.7536 - val_loss: 0.6382 - val_accuracy: 0.7619
# Epoch 16/100
# 126/126 [==============================] - 514s 4s/step - loss: 0.6356 - accuracy: 0.7667 - val_loss: 0.6395 - val_accuracy: 0.7688
# Epoch 17/100
# 126/126 [==============================] - 525s 4s/step - loss: 0.6328 - accuracy: 0.7710 - val_loss: 0.6382 - val_accuracy: 0.7659
# Epoch 18/100
# 126/126 [==============================] - 509s 4s/step - loss: 0.6232 - accuracy: 0.7742 - val_loss: 0.6412 - val_accuracy: 0.7668
# Epoch 19/100
# 126/126 [==============================] - 514s 4s/step - loss: 0.6026 - accuracy: 0.7803 - val_loss: 0.6335 - val_accuracy: 0.7634
# Epoch 20/100
# 126/126 [==============================] - 509s 4s/step - loss: 0.6007 - accuracy: 0.7762 - val_loss: 0.6299 - val_accuracy: 0.7649
# Epoch 21/100
# 126/126 [==============================] - 512s 4s/step - loss: 0.5832 - accuracy: 0.7852 - val_loss: 0.6268 - val_accuracy: 0.7678
# Epoch 22/100
# 126/126 [==============================] - 510s 4s/step - loss: 0.5747 - accuracy: 0.7897 - val_loss: 0.6246 - val_accuracy: 0.7728
# Epoch 23/100
# 126/126 [==============================] - 516s 4s/step - loss: 0.5596 - accuracy: 0.7902 - val_loss: 0.6219 - val_accuracy: 0.7664
# Epoch 24/100
# 126/126 [==============================] - 509s 4s/step - loss: 0.5614 - accuracy: 0.7893 - val_loss: 0.6216 - val_accuracy: 0.7698
# Epoch 25/100
# 126/126 [==============================] - 513s 4s/step - loss: 0.5406 - accuracy: 0.8025 - val_loss: 0.6272 - val_accuracy: 0.7664
# Epoch 26/100
# 126/126 [==============================] - 514s 4s/step - loss: 0.5353 - accuracy: 0.8015 - val_loss: 0.6209 - val_accuracy: 0.7748
# Epoch 27/100
# 126/126 [==============================] - 509s 4s/step - loss: 0.5163 - accuracy: 0.8109 - val_loss: 0.6135 - val_accuracy: 0.7718
# Epoch 28/100
# 126/126 [==============================] - 512s 4s/step - loss: 0.5213 - accuracy: 0.8074 - val_loss: 0.6250 - val_accuracy: 0.7728
# Epoch 29/100
# 126/126 [==============================] - 511s 4s/step - loss: 0.5151 - accuracy: 0.8143 - val_loss: 0.6278 - val_accuracy: 0.7634
# Epoch 30/100
# 126/126 [==============================] - 511s 4s/step - loss: 0.5000 - accuracy: 0.8171 - val_loss: 0.6111 - val_accuracy: 0.7733
# Epoch 31/100
# 126/126 [==============================] - 511s 4s/step - loss: 0.4953 - accuracy: 0.8175 - val_loss: 0.6168 - val_accuracy: 0.7773
# Epoch 32/100
# 126/126 [==============================] - 514s 4s/step - loss: 0.4925 - accuracy: 0.8185 - val_loss: 0.6170 - val_accuracy: 0.7833
# Epoch 33/100
# 126/126 [==============================] - 509s 4s/step - loss: 0.4927 - accuracy: 0.8189 - val_loss: 0.6261 - val_accuracy: 0.7733
# Epoch 34/100
# 126/126 [==============================] - 523s 4s/step - loss: 0.4890 - accuracy: 0.8178 - val_loss: 0.6050 - val_accuracy: 0.7828
# Epoch 35/100
# 126/126 [==============================] - 524s 4s/step - loss: 0.4703 - accuracy: 0.8248 - val_loss: 0.6272 - val_accuracy: 0.7748
# Epoch 36/100
# 126/126 [==============================] - 512s 4s/step - loss: 0.4632 - accuracy: 0.8256 - val_loss: 0.6228 - val_accuracy: 0.7763
# Epoch 37/100
# 126/126 [==============================] - 512s 4s/step - loss: 0.4451 - accuracy: 0.8375 - val_loss: 0.6079 - val_accuracy: 0.7788
# Epoch 38/100
# 126/126 [==============================] - 507s 4s/step - loss: 0.4424 - accuracy: 0.8359 - val_loss: 0.6221 - val_accuracy: 0.7798
# Epoch 39/100
# 126/126 [==============================] - 514s 4s/step - loss: 0.4293 - accuracy: 0.8420 - val_loss: 0.6294 - val_accuracy: 0.7763
# Epoch 40/100
# 126/126 [==============================] - 511s 4s/step - loss: 0.4248 - accuracy: 0.8415 - val_loss: 0.6204 - val_accuracy: 0.7893
# Epoch 41/100
# 126/126 [==============================] - 527s 4s/step - loss: 0.4149 - accuracy: 0.8499 - val_loss: 0.6312 - val_accuracy: 0.7743
# Epoch 42/100
# 126/126 [==============================] - 510s 4s/step - loss: 0.4127 - accuracy: 0.8450 - val_loss: 0.6279 - val_accuracy: 0.7778
# Epoch 43/100
# 126/126 [==============================] - 518s 4s/step - loss: 0.4019 - accuracy: 0.8528 - val_loss: 0.6312 - val_accuracy: 0.7768
# Epoch 44/100
# 126/126 [==============================] - 510s 4s/step - loss: 0.4066 - accuracy: 0.8462 - val_loss: 0.6330 - val_accuracy: 0.7773
# Epoch 45/100
# 126/126 [==============================] - 508s 4s/step - loss: 0.3973 - accuracy: 0.8545 - val_loss: 0.6325 - val_accuracy: 0.7783
# Epoch 46/100
# 126/126 [==============================] - 514s 4s/step - loss: 0.3882 - accuracy: 0.8565 - val_loss: 0.6374 - val_accuracy: 0.7768
# Epoch 47/100
# 126/126 [==============================] - 508s 4s/step - loss: 0.3919 - accuracy: 0.8506 - val_loss: 0.6483 - val_accuracy: 0.7788
# Epoch 48/100
# 126/126 [==============================] - 512s 4s/step - loss: 0.3807 - accuracy: 0.8577 - val_loss: 0.6410 - val_accuracy: 0.7793
# Epoch 49/100
# 126/126 [==============================] - 510s 4s/step - loss: 0.3724 - accuracy: 0.8602 - val_loss: 0.6318 - val_accuracy: 0.7808
# Epoch 50/100
# 126/126 [==============================] - 514s 4s/step - loss: 0.3679 - accuracy: 0.8646 - val_loss: 0.6450 - val_accuracy: 0.7768

# %%
y_hatt = model.predict(X_test)
a = np.argmax(y_hatt, axis =1 )
b = np.argmax(y_test,axis =1)
from sklearn.metrics import classification_report 
print(classification_report(a, b))
from sklearn.metrics import confusion_matrix
a = np.argmax(y_hatt, axis =1 )
b = np.argmax(y_test,axis =1)
cm =confusion_matrix(a, b)
import seaborn as sns
plt.figure()
sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)       
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 63/63 [==============================] - 106s 2s/step
#               precision    recall  f1-score   support
#
#            0       0.94      0.87      0.91      1456
#            1       0.36      0.58      0.44       133
#            2       0.59      0.59      0.59       243
#            3       0.54      0.52      0.53        89
#            4       0.42      0.45      0.44        55
#            5       0.61      0.86      0.72        22
#            6       0.15      0.80      0.26         5
#
#     accuracy                           0.79      2003
#    macro avg       0.52      0.67      0.55      2003
# weighted avg       0.82      0.79      0.80      2003

# %% [markdown]
# Now, you have data X_train, X_test and labels y_train, y_test. Create a deep learning model or (even better) use transfer learning on a pretrained model eg. Inception or any other found in eg. https://keras.io/api/applications/ ), train it properly and make predictions using it. You need get extract important metrics as well.
#
# To be clear you need to define the model and the metrics. For example the 'classification_report' in sklearn is good way to check performance. Plotting a confusion matrix is another.
#
# Make sure that your trained model doesn't get stuck in thinking everything is the same class.
#
# Remember that this dataset is in color. That means your images has a "depth". Make sure you define this appropriately when you define your model. Keep in mind the number of classes/targets you have here and in what format ("one-hot encoded eg [1 0 0, 0 1 0, 0 0 1] or as "numbers" [0,1,2].
#
# **When you have finished this assignment , save this notebook and submit it in Canvas. For the submission you only need to use the HAM1400_100_75 dataset and show the results (confusion matrix or classification report or similar, accuracy alone is not ok).**
